# %%
import pandas as pd

# %%
df=pd.read_csv('G://OneDrive//tmdb.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
df.shape
# Out:
# (10866, 21)

# %%
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df=df.drop(['imdb_id','tagline','homepage'],axis=1)

# %%
df
# Out:
#            id  popularity     budget     revenue  \
# 0      135397   32.985763  150000000  1513528810
# 1       76341   28.419936  150000000   378436354
# 2      262500   13.112507  110000000   295238201
# 3      140607   11.173104  200000000  2068178225
# 4      168259    9.335014  190000000  1506249360
# ...       ...         ...        ...         ...
# 10861      21    0.080598          0           0
# 10862   20379    0.065543          0           0
# 10863   39768    0.065141          0           0
# 10864   21449    0.064317          0           0
# 10865   22293    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...                             ...
# 10861            The Endless Summer
# 10862                    Grand Prix
# 10863           Beregis Avtomobilya
# ...

# %%
df.shape
# Out:
# (10866, 18)

# %%
df=df.dropna()

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8667 entries, 0 to 10865
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    8667 non-null   int64
#  1   popularity            8667 non-null   float64
#  2   budget                8667 non-null   int64
#  3   revenue               8667 non-null   int64
#  4   original_title        8667 non-null   object
#  5   cast                  8667 non-null   object
#  6   director              8667 non-null   object
#  7   keywords              8667 non-null   object
#  8   overview              8667 non-null   object
#  9   runtime               8667 non-null   int64
#  10  genres                8667 non-null   object
#  11  production_companies  8667 non-null   object
#  12  release_date          8667 non-null   object
#  13  vote_count            8667 non-null   int64
#  14  vote_average          8667 non-null   float64
# ...

# %%
 #Movie with the third highest budget?
    
h=df.sort_values(by='budget',ascending=False)
h[:3]
# Out:
#          id  popularity     budget     revenue  \
# 2244  46528    0.250540  425000000    11087569
# 3375   1865    4.955130  380000000  1021683000
# 7387    285    4.965391  300000000   961000000
#
#                                    original_title  \
# 2244                            The Warrior's Way
# 3375  Pirates of the Caribbean: On Stranger Tides
# 7387     Pirates of the Caribbean: At World's End
#
#                                                    cast        director  \
# 2244  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...      Sngmoo Lee
# 3375  Johnny Depp|PenÃ©lope Cruz|Geoffrey Rush|Ian M...    Rob Marshall
# 7387  Johnny Depp|Orlando Bloom|Keira Knightley|Geof...  Gore Verbinski
#
#                                                keywords  \
# 2244  assassin|small town|revenge|deception|super speed
# 3375            sea|captain|mutiny|sword|prime minister
# 7387  ocean|drug abuse|exotic island|east india trad...
#
# ...

# %%
 #Movie with the third lowest budget?
    
h=df.sort_values(by='budget')
h[:3]
# Out:
#           id  popularity  budget  revenue                original_title  \
# 5714  214093    0.380585       0        0  L'Amour Est un Crime Parfait
# 7660   13949    0.276624       0        0                    Persuasion
# 7657    7797    0.281136       0        0           Youth Without Youth
#
#                                                    cast  \
# 5714  Mathieu Amalric|MaÃ¯wenn|Karin Viard|Denis Pod...
# 7660  Sally Hawkins|Rupert Penry-Jones|Alice Krige|A...
# 7657  Tim Roth|Alexandra Maria Lara|Bruno Ganz|AndrÃ...
#
#                                director  \
# 5714  Arnaud Larrieu|Jean-Marie Larrieu
# 7660                    Adrian Shergold
# 7657               Francis Ford Coppola
#
#                                                keywords  \
# 5714              thriller|teacher student relationship
# 7660             love triangle|poetry|captain|navy|love
# 7657  fountain of youth|nepal|soulmates|dual identit...
#
# ...

# %%
## Average number of words in movie titles between the year 2000-2005

##YEAR 2000

y=df[df['release_year'] ==2000]
  
l=[]
for i in y.original_title:
    e=i.replace(" ",'')
    l.append(len(e))

    
print(sum(l)/len(l))
# Out:
# 13.369565217391305

# %%
##YEAR 2001
y1=df[df['release_year']==2001]
  
l1=[]
for i in y1.original_title:
    e=i.replace(" ",'')
    l1.append(len(e))

print(sum(l1)/len(l1))
# Out:
# 13.494897959183673

# %%
##YEAR 2002

y2=df[df['release_year']==2002]
  
l2=[]
for i in y2.original_title:
    e=i.replace(" ",'')
    l2.append(len(e))

print(sum(l2)/len(l2))
# Out:
# 13.269406392694064

# %%
##YEAR 2003
y3=df[df['release_year']==2003]
  
l3=[]
for i in y3.original_title:
    e=i.replace(" ",'')
    l3.append(len(e))

print(sum(l3)/len(l3))
# Out:
# 14.098130841121495

# %%
##YEAR 2004
y4=df[df['release_year']==2004]
  
l4=[]
for i in y4.original_title:
    e=i.replace(" ",'')
    l4.append(len(e))

print(sum(l4)/len(l4))
# Out:
# 15.050632911392405

# %%
##YEAR 2005
y5=df[df['release_year']==2005]
  
l5=[]
for i in y5.original_title:
    e=i.replace(" ",'')
    l5.append(len(e))

print(sum(l5)/len(l5))
# Out:
# 13.816053511705686

# %%
##AVERAGE WORDS 

print((sum(l)/len(l)+sum(l1)/len(l1)+sum(l2)/len(l2)+sum(l3)/len(l3)+sum(l4)/len(l4)+sum(l5)/len(l5))/6)
# Out:
# 13.849781138914773

# %%
## Least revenue 
r=df.sort_values(by='revenue')
r
# Out:
#           id  popularity     budget     revenue                original_title  \
# 5714  214093    0.380585          0           0  L'Amour Est un Crime Parfait
# 6342    9721    0.481416   13000000           0                     7 Seconds
# 6340   10292    0.498926    3500000           0    Urban Legends: Bloody Mary
# 6339   10064    0.499629          0           0                        Edison
# 6336   15657    0.506241          0           0                     Tarzan II
# ...      ...         ...        ...         ...                           ...
# 0     135397   32.985763  150000000  1513528810                Jurassic World
# 4361   24428    7.637767  220000000  1519557910                  The Avengers
# 5231     597    4.355219  200000000  1845034188                       Titanic
# 3     140607   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 1386   19995    9.432768  237000000  2781505847                        Avatar
#
# ...

# %%
## Highest revenue 
r1=df.sort_values(by='revenue',ascending=False)
r1
# Out:
#            id  popularity     budget     revenue  \
# 1386    19995    9.432768  237000000  2781505847
# 3      140607   11.173104  200000000  2068178225
# 5231      597    4.355219  200000000  1845034188
# 4361    24428    7.637767  220000000  1519557910
# 0      135397   32.985763  150000000  1513528810
# ...       ...         ...        ...         ...
# 5063    10922    0.471245   30000000           0
# 5061    10943    0.477180          0           0
# 5058    10628    0.490786          0           0
# 5056     2577    0.496760    7500000           0
# 10865   22293    0.035919      19000           0
#
#                      original_title  \
# 1386                         Avatar
# 3      Star Wars: The Force Awakens
# 5231                        Titanic
# 4361                   The Avengers
# 0                    Jurassic World
# ...                             ...
# 5063                The Human Stain
# 5061                  The Gathering
# 5058                  Kangaroo Jack
# ...

# %%
## AVERAGE RUNTIME 2006 
run=df[df['release_year']==2006]

l=[]
for i in run.runtime:
    l.append(i)
    
    
print(sum(l)/len(l))
# Out:
# 101.98769230769231
